# %% [markdown]
# <a href="https://colab.research.google.com/github/swarnamouli/swarna1924/blob/master/Medical_Services.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
# Importing Libraries
import numpy as np
import pandas as pd
from geopy.geocoders import Nominatim
from google.colab import files
from scipy.spatial import distance

# %%
geolocator = Nominatim(user_agent="specify_your_app_name_here")
location = geolocator.geocode("1627 N Tibbs Ave, Indianapolis")
print(location.address)
print(location.latitude, location.longitude)

current_location = (39.780408, -86.216067)
current_location2 = (-86.216067, 39.780408)
# Out:
# North Tibbs Avenue, Indianapolis, Marion County, Indiana, 46222, USA
# 39.780408 -86.216067

# %% [markdown]
# # Importing the data

# %%
# Importing the data
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bffceeb7-11aa-4b0d-b172-8a96e2e6000d" name="files[]" multiple disabled />
#      <output id="result-bffceeb7-11aa-4b0d-b172-8a96e2e6000d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HandiData.csv to HandiData (1).csv

# %%
# Loading the data into a dataframe
data_df = pd.read_csv("HandiData.csv") 
data_df.head()
# Out:
#                      Disability Service Type  ...   Latitude
# 0  Blind & Visually Impaired Services (BVIS)  ...  39.454628
# 1  Blind & Visually Impaired Services (BVIS)  ...  39.898620
# 2  Blind & Visually Impaired Services (BVIS)  ...  39.770660
# 3  Blind & Visually Impaired Services (BVIS)  ...  40.195520
# 4  Blind & Visually Impaired Services (BVIS)  ...  41.031610
#
# [5 rows x 8 columns]

# %%
# Latitude and Longitude
data_gps = data_df[['Latitude', 'Longitude']]
data_gps
# Out:
#      Latitude  Longitude
# 0   39.454628 -87.415290
# 1   39.898620 -86.259865
# 2   39.770660 -86.080248
# 3   40.195520 -85.387630
# 4   41.031610 -85.112750
# 5   39.829419 -84.929998
# 6   37.974167 -87.556407
# 7   39.467117 -87.405750
# 8   41.678206 -86.248046
# 9   39.862370 -86.119330
# 10  38.319267 -85.757996
# 11  40.191086 -85.385390
# 12  41.050100 -85.134550
# 13  37.990738 -87.529190
# 14  41.451275 -87.331490
# 15  41.466460 -87.297500
# 16  39.843060 -86.120766
# 17  39.984932 -85.992640
# 18  38.336120 -85.830765
# 19  41.031610 -85.112750
# 20  41.723001 -86.179003
# 21  37.966698 -87.566720
# 22  38.674550 -87.535400
# 23  39.484780 -87.410290
# 24  41.595257 -87.242110
# 25  41.488758 -87.054010
# 26  40.420073 -86.869466
# 27  41.665650 -86.840324
# 28  41.287907 -86.612770
# 29  39.758219 -86.437257
# ..        ...        ...
# 32  39.777550 -86.182880
# 33  39.769960 -86.159940
# 34  40.446620 -86.127080
# 35  39.646020 -86.120620
# 36  39.795574 -86.045530
# ...

# %%
haversine(-87.415290, 39.454628	, -86.216067, 39.780408 )
# Out:
# 108.91931948460898

# %% [markdown]
# # Nearest Volunteers

# %%
# Nearest Volunteers

# %%
a = data_gps.values

b = np.array([[ 39.780408, -86.216067]])
d = distance.cdist(a, b, 'cityblock')
df_dist = pd.DataFrame(data =d, columns=['distances'])
data_df['distances'] = df_dist
data_df

nearest_volunteers = data_df.sort_values(by=['distances'])
nearest_volunteers
# Out:
#                               Disability Service Type  ... distances
# 31         Adult Mental Health Habilitation Services   ...  0.036045
# 32         Adult Mental Health Habilitation Services   ...  0.036045
# 55                     Opioid Treatment Program (OTP)  ...  0.060425
# 33         Adult Mental Health Habilitation Services   ...  0.066575
# 2           Blind & Visually Impaired Services (BVIS)  ...  0.145567
# 56                     Opioid Treatment Program (OTP)  ...  0.156315
# 16           Deaf and Hard of Hearing Services (DHHS)  ...  0.157953
# 1           Blind & Visually Impaired Services (BVIS)  ...  0.162010
# 9   Bureau of Developmental Disabilities Services ...  ...  0.178699
# 36         Adult Mental Health Habilitation Services   ...  0.185703
# 35         Adult Mental Health Habilitation Services   ...  0.229835
# 29         Adult Mental Health Habilitation Services   ...  0.243379
# 17           Deaf and Hard of Hearing Services (DHHS)  ...  0.427951
# ...

# %% [markdown]
# # Nearest 5 volunteers

# %%
nearest_volunteers.head()
# Out:
#                        Disability Service Type  ... distances
# 31  Adult Mental Health Habilitation Services   ...  0.036045
# 32  Adult Mental Health Habilitation Services   ...  0.036045
# 55              Opioid Treatment Program (OTP)  ...  0.060425
# 33  Adult Mental Health Habilitation Services   ...  0.066575
# 2    Blind & Visually Impaired Services (BVIS)  ...  0.145567
#
# [5 rows x 9 columns]

# %% [markdown]
# # Sending Alert Messages
